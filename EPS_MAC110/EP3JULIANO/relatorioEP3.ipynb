# %% [markdown]
# <h4>Juliano Garcia de Oliveira</h4>
# <h6> OBS: Todas as imagens mostradas aqui estão disponíveis em um <a href="http://imgur.com/a/bTRbE"> Álbum no Imgur </a> online.
# <center><h3> Relatório - EP3 </h3></center>
# <h2> Transformações Sobre listas Uniformes </h2>
#
# <p>Na primeira parte do EP3, implementei as funções de transformação em uma lista com valores uniformemente distribuídos. Os valores foram gerados através de números randômicos entre 10⁻¹⁵ e 1 (O número 0 não poderia ser incluído para não dar erro em algumas funções). </p>
# <h5> Transformação Escalar </h5>
# <p> Nessa função do EP3, a lista uniforme tinha seus valores transformados a partir de valores reais 'a' e 'b' inseridos pelo usuário. A função fazia a "translação" dos valores iniciais da lista (aproximadamente entre 0 e 1), para valores seguindo a regra:<i><b> a + U[i]*(b-a+1) </b> </i> , onde U[i] é um elemento da lista uniforme.</p>
# <p> O resultado foi uma mudança no eixo X, ou seja, o gráfico foi deslocado ("transaladado"), dependendo dos valores de <i><b> 'a' e 'b' </b></i> . O histograma continuou característico de uma distribuição uniforme. Abaixo segue uma imagem do resultado da transformação escalar, para valores de <i><b> a = 20 e b = 1000 </b></i> </p>
# <img  src="http://i.imgur.com/OYQZzrq.png">
# <h5> Soma de Vetores </h5>
# <p> Nessa função do EP3, duas listas com valores uniformemente distribuídos no intervalo <i><b> ]0,1] </b></i> tinham todos os seus valores somados, 1 a 1. A forma do histograma gerado é uma espécie de pirâmide, já que os valores iniciais estavam entre <i><b> ]0,1] </b></i> , uniformemente distribuídos, a maior parte dos valores está perto do valor 1, e vai decaindo simetricamente tanto para 0, quanto para valores maiores que 1.5, que são  valores mais raros de se obter na soma desses números no intervalo em questão. A imagem abaixo mostra o histograma gerado para este tipo de transformação. </p>
# <img  src="http://i.imgur.com/k4thKx6.png">
# <h5> Raiz de Vetor </h5>
# <p> Nessa função do EP3, uma lista era transformada para que posição recebesse a raiz do valor armazenado anteriormente: <i><b> &radic;U[i] </b></i>. Como os valores inicias de U estão uniformemente distribuídos no intervalo <i><b> ]0,1] </b></i>, e como a raiz de um número nesse intervalo sempre dá um número maior que ele mesmo (exceção para o 1), houve a formação de um histograma com forma "escada", já que todos os valores geram um número maior que o original, a frequência é deslocada para números maiores. É fácil de perceber isto no histograma a seguir. </p>
# <img  src="http://i.imgur.com/eTzXzlh.png">
# <h5> Transformação Box-Muller</h5>
# <p> Nessa função do EP3, se aplica a <a href="https://en.wikipedia.org/wiki/Box%E2%80%93Muller_transform">tranformação Box-Muller</a> em duas listas uniformes no intervalo <i><b> ]0,1] </b></i>, gerando duas listas diferentes. A transformação usa uma fórmula que é melhor explicada no link anterior, mas o fato é que ela gera um histograma de distribuição de Gauss (ou distribuição normal), como mostram as imagens dos dois histogramas gerados por essa função.  </p>
# <img  src="http://i.imgur.com/R8UL2JL.png">
# <img  src="http://i.imgur.com/Dw67Iyi.png">
#
# <hr>
# <h2> Análise da distribuição de cordas geradas no EP2 </h2>
# <h4> OBS: Todas as imagens nesta seção, com exceção da Distribuição de Cordas, foram geradas com o parâmetro <i><b> n = 50000 </b></i> e <i><b> raio = 100 </b></i>.
# <h5> Distribuição Borda </h5>
# <p> Nessa função do EP3, é verificada como fica a distribuição dos pontos através da borda, ou seja, os pontos na circunferência. Em todos os casos (M1,M2 e M3) os pontos foram distríbuidos uniformemente. As imagens geradas são mostradas a seguir. </p>
# <center><h3> Distribuição Borda: Método1</h3></center>
# <img  src="http://i.imgur.com/YSD45nJ.png">
# <center><h3> Distribuição Borda: Método2</h3></center>
# <img  src="http://i.imgur.com/M0rK15T.png">
# <center><h3>  Distribuição Borda: Método3</h3></center>
# <img  src="http://i.imgur.com/kYl5cns.png">
# <h5> Distribuição Radial </h5>
# <p> Nessa função do EP3, é verificada como fica a distribuição dos pontos médios radialmente. Aqui já aparecem diferenças bastante significantes entre os diferentes métodos de gerar cordas. Quanto mais uniforme for essa distribuição, a frequência de cordas que possuem lado maior que o triângulo equilátero inscrito no círculo se aproxima de 50%.  </p>
# <h5> Método 1 </h5>
# <p>Inicialmente, no Método 1, temos uma distribuição desigual, na qual a maior parte dos pontos médios está na divisão mais próxima à circunferência. No cálculo da probabilidade, isso influencia na quantidade de vezes que uma corda irá ser maior que o lado do triângulo equilátero inscrito nessa circunferência. Na figura do Método 1 abaixo, temos que a soma das categorias <i><b> C1,C2,C3 e C4 </b></i>(que são as categorias cujos pontos médios geram corda maior que o lado do triângulo equiĺátero inscrito na circunferência) é aproximadamente <i><b> 16700</b></i>, ou seja, <i><b> frequência relativa de 33,4%</b></i>, que é a probabilidade esperada no EP2 para este Método. </p>
# <center><h3> Distribuição Radial: Método1</h3></center>
# <img  src="http://i.imgur.com/dssIhxF.png">
# <h5> Método 2 </h5>
# <p>A distribuição radial no Método 2 é praticamente uma distribuição uniforme. É fácil perceber que  a soma das frequências absolutas das  categorias <i><b> C1,C2,C3 e C4 </b></i>equivale a metade do total de barras (ou seja, 50%, já que é uma distribuição praticamente uniforme).Isso mostra porque a probabilidade deste método no EP2 resulta em 0,5 (50%), já que metade das vezes a corda é maior que o triângulo equilátero inscrito na circunferência. </p>
# <center><h3> Distribuição Radial: Método2</h3></center>
# <img  src="http://i.imgur.com/w8HEzfP.png">
# <h5> Método 3 </h5>
# <p>Já no método 3, é a situação na qual a soma das categorias  <i><b> C1,C2,C3 e C4 </b></i> é a menor de todas as somas, que dá uma frequência absoluta de aproximadamente 12400, ou seja, frequência relativa de 24,8% muito próximo da probabilidade esperada deste Método no EP2, que é de 25% das vezes. A imagem abaixo mostra claramente esta distribuição, que é semelhante é
# equivale a metade do total de barras (ou seja, 50%, já que é uma distribuição praticamente uniforme).Isso mostra porque a probabilidade deste método no EP2 resulta em 0,5 (50%), já que metade das vezes a corda é maior que o triângulo equilátero inscrito na circunferência. </p>
# <center><h3> Distribuição Radial: Método3</h3></center>
# <img  src="http://i.imgur.com/Fb4W0UH.png">
# <h5> Distribuição Área </h5>
# <p> Nessa função do EP3, é verificada como fica a distribuição dos pontos médios em 8 partes do círculo de mesma área. O círculo foi dividido no estilo "Yin Yang", só que em 8 partes.</p>
# <p> <b> OBS: A minha divisão do círculo em 8 partes de mesma área está de acordo com a <u> Especificação do EP3</u>, que diz apenas para dividir o círculo em partes de mesma área, não falando como deve ser feita essa divisão especificamente. Portanto, as imagens aqui geradas (junto com os histogramas) são diferentes das 'Imagens Esperadas' que foi postada pelo professor no PACA, porém estão de acordo com o EP3.</b> </p>
# <h5> Método 1 </h5>
# <p>O histograma gerado pela distribuição de Área no Método 1 é bem característico, e é possível perceber uma maior concentração de pontos nas extremidades do círculo (as categorias <i><b> C1 e C8 </b></i> e nos pontos das categorias <i><b> C4 e C5 </b></i>. Nessas duas últimas categorias, temos pontos tanto das extremidades quanto da parte central do círculo. </p>
# <center><h3> Distribuição Área: Método1</h3></center>
# <img  src="http://i.imgur.com/Za5zYEP.png">
# <h5> Método 2 </h5>
# <p>No método 2, a distribuição dos pontos em áreas iguais do círculo é diferente. A maior parte dos pontos se encontra nas categorias <i><b> C4 e C5 </b></i>, cuja maior parte da área cobre o centro do círculo. Porém, parte do <i><b> C3 e C6 </b></i> também cobre essa parte central. É possível traçar um paralelo com esta situação com  distribuição radial deste método, já que sabemos que o número de pontos que atingem essa região central é aproximadamente 50%.</p>
# <center><h3> Distribuição Área: Método2</h3></center>
# <img  src="http://i.imgur.com/WBSfHOJ.png">
# <h5> Método 3 </h5>
# <p>É fácil perceber que no Método 3 a distribuição por área deveria ser uniforme, já que os pontos gerados pelo Método  do EP2 são pontos aleatórios dentro do círculo, e não pontos na circunferência. Portanto, são uniformemente distribuídos em todas as divisões de área do círculo em questão. A imagem a seguir mostra claramente um histograma característico de distribuição uniforme.</p>
# <center><h3> Distribuição Área: Método3</h3></center>
# <img  src="http://i.imgur.com/pDHbMl7.png">
# <h5> Distribuição Cordas </h5>
# <p> A última função do EP3, mostra a distribuição das cordas geradas por cada um dos métodos do EP2. Os valores utilizados nas imagens a seguir são de <i><b> n = 500 </b></i> e <i><b> raio = 100 </b></i>. Seja 'L' o lado do triângulo equilátero inscrito na circunferência.  As cordas em <font size="3" color="red">VERMELHO</font> possuem tamanho menor que 'L',  já as cordas representadas em <font size="3" color="green">VERDE</font> possuem tamanho maior que L. </p>
# <h5> Método 1 </h5>
# <p>A distribuição de cordas do método 1 é razoavelmente distribuída, porém se vê um acúmulo maior de cordas nas extremidades do círculo, o que também é possível perceber na distribuição radial deste método.</p>
# <center><h3> Distribuição de Cordas: Método1</h3></center>
# <img  src="http://i.imgur.com/wG93m8Z.png">
# <h5> Método 2 </h5>
# <p>A distribuição de cordas do método 2 é bastante uniforme, como se vê na figura a seguir. Era de se esperar,já que a distribuição radial deste método foi uniforme. Note a maior concentração de cordas verdes na imagem a seguir.</p>
# <center><h3> Distribuição de Cordas: Método2</h3></center>
# <img  src="http://i.imgur.com/kQPAWrW.png">
# <h5> Método 3 </h5>
# <p>Fica bastante evidente que no método 3 a quantidade de cordas que passam pelo área central é muito pequena. Olhando o histograma de distribuição radial, vemos que a quantidade de pontos que caem no centro é a menor de todas no círculo, por isso a menor concentração de cordas nessa região, além de possuir a menor probabilidade de uma corda ser maior que o lado do triângulo equilátero inscrito na circunferência.</p>
# <center><h3> Distribuição de Cordas: Método3</h3></center>
# <img  src="http://i.imgur.com/fQ2jAol.png">
